# %%
import numpy as np
import pandas as pd

# 1. Test NumPy: A 1D array of gene expression levels (in TPM - Transcripts Per Million)
expression_levels = np.array([12.5, 45.2, 0.8, 120.4, 3.1])
print(f"Mean Gene Expression: {expression_levels.mean():.2f} TPM")

# 2. Test Pandas: A mini clinical trial cohort table
clinical_data = pd.DataFrame({
    'Patient_ID': ['PT-001', 'PT-002', 'PT-003'],
    'Biomarker_Status': ['Positive', 'Negative', 'Positive'],
    'Tumor_Stage': ['Stage II', 'Stage I', 'Stage III']
})

print("\n--- Clinical Cohort Table ---")
clinical_data
# Out:
# Mean Gene Expression: 36.40 TPM
#
# --- Clinical Cohort Table ---
#   Patient_ID Biomarker_Status Tumor_Stage
# 0     PT-001         Positive    Stage II
# 1     PT-002         Negative     Stage I
# 2     PT-003         Positive   Stage III
