# %% [markdown]
# ## FUNCTIONS

# %% [markdown]
# A **function** is a named block of code. Before now, we have been using some Python built-in functions like print(), len(), input() and type(). Python allows users to create user-defined functions.
# To **define** a function, we need to specify its **name**, **parameters** (which are optional) and **block of code**. A function can also return result using the `return keyword`.
# Let's write an example of a user-defined function that returns True if a number is even, otherwise it returns False.

# %% [markdown]
# define the name of the function
# Lets have a parameter or not
# block of code (what the function should do)
# call the function
#
#
# write a function to add 2 numbers together
#
# def additionoftwonumbers(num1, num2):
#     result = num1 + num2
#     return result
#
#
# additionoftwonumbers(2, 3)

# %%
#write a function that shows if a number if even or odd number 

def numbers(x):
    if(x%2==0):
        print("The number is even number")
    else:
        print("The number is odd number")    
        
        
#call a function with the name 
numbers(7) #call the function then I also pass the argument (value)
# Out:
# The number is odd number

# %%
#write a function to add 2 numbers together 

def additionoftwonumbers(num1,num2):
    result = num1 + num2 
    return result

# %%
additionoftwonumbers(2, 13)
# Out:
# 15

# %%
def functionname(parameter):
    
    return

# %%
#write python function to show if a number is even or not
def myevenfunction(number): #number here is parameter 
    if(number % 2 == 0):
        print("The number is even")
    else:
        print("The number is odd")

# %%
myevenfunction(8)  #values is the argument
# Out:
# The number is even

# %%
#to call a function 

myevenfunction(7) #pass the argument to the function
# Out:
# The number is odd

# %%
#write a function to add two numbers together 
def sums(num1, num2):
    result = num1 + num2 
    print("The sum of the two numbers is",result)  #the comma is concatenation in python 
    #return result

# %%
sums(14,10)
# Out:
# The sum of the two numbers is 24

# %%
def mult (num1, num2 , num3):
    result =num1 * num2 * num3
    print ("the multiple of the three numbers",result)

mult (5,9,7)
# Out:
# the multiple of the three numbers 315

# %% [markdown]
# As seen in the example above, we used the **def** keyword to define a function. A function can have parameters. A **parameter** is a variable name specified within the **parenthesis** in a **function definition**. Functions may or may not return a value, the **return** keyword is used to make a function return a result. Values returned by functions can be saved to a variable for later use.
# To use a function, you have to **call** it by its **name** and pass the necessary **arguments** if any is required. An **argument** is a value passed to the **function's parameters** when the function is called.

# %%
def even (num):
    if (num%2==0):
        print(num, "is an even number")
    else:
        print (num, "is an odd number")

even(8)
# Out:
# 8 is an even number

# %%
even(5)
# Out:
# 5 is an odd number

# %%
def word(): #parameterless function
    print("welcome to school")

# %%
word()
# Out:
# welcome to school

# %% [markdown]
# As seen above, the function is_even() was called with 8 and 5 as arguments.

# %% [markdown]
# We can also have functions that do not return any value. Such functions might just be used to display an output, perform some calculations or modify some variables. Let's see an example of a function that does not return a value but just prints even numbers between 1 and a specified number (inclusive).

# %%
a = [1,2,3,4]
for dd in a:
    print(dd)
# Out:
# 1
# 2
# 3
# 4

# %%
colors = ['red', 'blue', 'yellow']

for color in colors:
    print (color)
# Out:
# red
# blue
# yellow

# %%
print(colors)
# Out:
# ['red', 'blue', 'yellow']

# %%
def even_numbers(n):
    if (n <= 1):
        print(n,'should be greater than 1.')
    else:
        for num in range(1, n+1): #iterator is used for loooping 
            if(num%2==0):
                print(num, "This is an even number")
            else:
                print(num, "This is an odd number")
                
            #if(myevenfunction(num)):
                #print (num)

# %%
even_numbers(5)
# Out:
# 1 This is an odd number
# 2 This is an even number
# 3 This is an odd number
# 4 This is an even number
# 5 This is an odd number

# %%
even_numbers(2)

result = even_numbers(12)  #function to an object
# Out:
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number

# %%
result = even_numbers(12)
# Out:
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number

# %%
even_numbers(9)
# Out:
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number
# This is an even number
# This is an odd number

# %% [markdown]
# For functions in which no value is returned using the `return keyword`, Python returns a `None` value as default. In the example below, the function `double` only doubles the argument and doesn't return any value.

# %%
def double(n):
    result =n**2
    return result

# %%
double(5)
# Out:
# 25

# %%
new = double(4)  #function to an object 
new #new is an object
# Out:
# 16

# %%
new
# Out:
# 16

# %%
result =double(4)  #making your function to become an object

# %%
result
# Out:
# 16

# %%
result = double(5) #makijg a function to become an object 
print(result) #printing my object named result
# Out:
# 25

# %% [markdown]
# ## DEFAULT PARAMETER VALUES

# %% [markdown]
# Function parameters can be assigned a default value during the function definition so that if the function is called without an argument, the default parameter value will be used. In a function definition, parameters with default values (optional parameters) should come after the required parameters.

# %%
def best_food(food='Chicken and chips'):
    
    print('My best food is', food)

# %%
best_food()
# Out:
# My best food is Chicken and chips

# %%
best_food("Garri and Epa")
# Out:
# My best food is Garri and Epa

# %%
best_food('Indomie and Egg')
# Out:
# My best food is Indomie and Egg

# %%
best_food()
# Out:
# My best food is Chicken and chips

# %%
def about_me(name='Israel', food='Chicken and chips'):
    print('My name is', name)
    print('My best food is', food)

# %%
about_me()
# Out:
# My name is Israel
# My best food is Chicken and chips

# %%
about_me('Aminat', 'Chicken Salad')
# Out:
# My name is Aminat
# My best food is Chicken Salad

# %%
about_me('Tolu', 'Moimoi Salad')
# Out:
# My name is Tolu
# My best food is Moimoi Salad

# %%
about_me('Oba', 'Roosted Yam')
# Out:
# My name is Oba
# My best food is Roosted Yam

# %%
about_me('Lukman', 'Egg roll')
# Out:
# My name is Lukman
# My best food is Egg roll

# %%
my_function = about_me('Dayo', 'Rice & Beanz')
# Out:
# My name is Dayo
# My best food is Rice & Beanz

# %%
my_function = about_me('Timileyin', 'Eko & Moimoi')
# Out:
# My name is Timileyin
# My best food is Eko & Moimoi

# %%
my_function = about_me('Opeyemi', 'pizza only')
# Out:
# My name is Opeyemi
# My best food is pizza only

# %% [markdown]
# ## KEYWORD ARGUMENTS

# %% [markdown]
# Arguments can be passed to functions using the **key = value syntax**. When using this syntax, the order in which the arguments are passed doesnt matter. Let's see an example of a function call with and without the key value syntax.

# %%
def person(name, gender, age):
    print ('My name is', name)
    print('I am a', gender)
    print('I am',age,'years old.')

# %%
person('Tom', 'male', 16)
# Out:
# My name is Tom
# I am a male
# I am 16 years old.

# %%
person(name='ola',age=56, gender='male')
# Out:
# My name is ola
# I am a male
# I am 56 years old.

# %% [markdown]
# ## ARBITRARY ARGUMENTS

# %% [markdown]
# A function can take a variable list of arguments. To define a function that takes any number of arguments, we use **`*`** before the parameter name in the function definition. This **`*`** tells Python to gather all the arguments into a tuple (a datastructure we would discuss later) of the named parameter.

# %%
def Addition (*numbers):  #5,6,7
    total = 0
    for number in numbers:
        total+= number
    return total

# %%
Addition(3,3,6,8,9,12)
# Out:
# 41

# %%
print(Addition(3,5,7,7))
# Out:
# 22

# %%
def Adds(*args):
    return sum(*args)

# %%
#Adds(12,45)

# %% [markdown]
# ## RECURSSIVE FUNCTIONS

# %% [markdown]
# A recurssive function is a function that calls itself within its function definition. It is a mathematical and programming concept that loops through data to attain a result. Recurssion is a very effective approach to programming if it is written very well.

# %%
def factorial(n): #using iteration
    if (n == 0 or n == 1):
        return 1
    answer = 1
    for i in range(n,0,-1):
        answer*=i
    return answer

#calling the function
factorial(5)
# Out:
# 120

# %%
def recursive_factorial(n):
    if n == 0 or n == 1: #base case
        return 1
    ans = n * recursive_factorial(n-1) #recursive case
    return ans

# %%
recursive_factorial(4)
# Out:
# 24

# %%
def recursive_fibonacci (n):
    if (n == 1 or n == 0): #base case
        return 1
    ans = recursive_fibonacci(n-2) + recursive_fibonacci(n-1)#recursive case
    return ans

recursive_fibonacci(2)
# Out:
# 2

# %% [markdown]
# ## SCOPE
# A variable is only available from inside the region it is created. This is called scope. We have 2 types of scope:
# 1. **Local scope:** A variable created inside a function belongs to the local scope of that function and can only be used inside that function.
# 2. **Global scope:** A variable created outside a function or within the main part of a Python code belongs to a global scope. It is available for use both locally and globally.

# %%
# global variables
name = 'Amanda'
age = 20
nationality = 'Nigerian'
color = 'blue'
    
def person(name, age, nationality, color):
    #using the name and age local variables and the nationality global variable 
    #when using the format method, {} is a placeholder 
    print(f"My name is {name}. I am a {nationality}. I am {age} years old. my favourite colour is {color}")

# %%
person(name, age, nationality,color)
# Out:
# My name is Amanda. I am a Nigerian. I am 20 years old. my favourite colour is blue

# %%
person('Brian', 25, nationality, color)
# Out:
# My name is Brian. I am a Nigerian. I am 25 years old. my favourite colour is blue

# %%
person('Fuad', 23, nationality, color)
# Out:
# My name is Fuad. I am a Nigerian. I am 23 years old. my favourite colour is blue

# %%
#Accessing the global variables 
print(f"My name is {name}. I am a {nationality}. I am {age} years old.")
# Out:
# My name is Amanda. I am a Nigerian. I am 20 years old.

# %% [markdown]
# ## THE GLOBAL KEYWORD
# We can create or modify a global variable within a function using the global keyword. if we do not put the global keyword in the function before calling or using the variable, Python will create the variable as a new local variable.  Lets see an example.

# %%
nationality = 'Nigerian'   
def person(name, age):
    global nationality
    print(f"My name is {name}. I am a {nationality}. I am a {age} years old.")

# %%
person('Brian', 25)
# Out:
# My name is Brian. I am a Nigerian. I am a 25 years old.

# %%
a = 5
b = 10
c = 4

def multiply(a, b):
    #locally created variable c
    c = 7
    print('Local C value ',c)
    return a * b * c


print ('Global C Value',c)
# Out:
# Global C Value 4

# %%
multiply (a,b)
# Out:
# Local C value  7
# 350

# %%
a = 5
b = 10
c = 4

def multiply(a, b):
    global c
    c = 10
    print('C value ',c)
    return a * b * c

print(multiply(2,4))

print ('Global C Value',c)
# Out:
# C value  10
# 80
# Global C Value 10

# %% [markdown]
# ## EXERCISE: PRIME NUMBERS

# %% [markdown]
# Write a function that prints all prime numbers up to a specified number.

# %%
def print_primes_up_to(limit):
    for num in range(2, limit + 1):
        is_prime = True
        for i in range(2, int(num ** 0.5) + 1):
            if num % i == 0:
                is_prime = False
                break
        if is_prime:
            print(num)

# Example usage
upper_limit = int(input("Enter the upper limit: "))
print_primes_up_to(upper_limit)
# Out:
# Enter the upper limit:  20
# 2
# 3
# 5
# 7
# 11
# 13
# 17
# 19

# %% [raw]
# def print_primes_up_to(limit):
# This line defines a function named print_primes_up_to that takes a single parameter called limit. The function's purpose is to print all prime numbers up to the specified limit.
#
#     for num in range(2, limit + 1):
# This line starts a for loop that iterates through numbers from 2 to the specified limit (inclusive). We start from 2 because 1 is not considered a prime number.
#
#         is_prime = True
# This line initializes a Boolean variable named is_prime to True. This variable will be used to track whether the current number being checked is prime or not.
#
#         for i in range(2, int(num ** 0.5) + 1):
# This line starts an inner for loop that iterates through numbers from 2 to the square root of the current number (num). The int(num ** 0.5) calculates the integer square root of num (to avoid checking unnecessary factors).
#
#             if num % i == 0:
#                 is_prime = False
#                 break
# Within the inner loop, this if statement checks if the current number (num) is divisible evenly by the current factor (i). If it is, that means the number is not prime, so is_prime is set to False, and the loop is exited using the break statement.
#
#         if is_prime:
#             print(num)
# After the inner loop, this if statement checks if the is_prime variable is still True. If it is, then the current number (num) is prime, and it is printed using the print() function.
#
# upper_limit = int(input("Enter the upper limit: "))
# print_primes_up_to(upper_limit)
# These lines allow the user to input an upper limit for prime number printing. The input() function prompts the user to enter a number, and int() converts the input to an integer. The print_primes_up_to() function is then called with the user-specified upper_limit as an argument to print the prime numbers up to that limit.
