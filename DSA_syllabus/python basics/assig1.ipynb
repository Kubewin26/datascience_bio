# %% [raw]
# Write a conditional statement to check the WAEC grade of a student e.g f9, D7, till AI

# %%
#Write a conditional statement to check the WAEC grade of a student e.g f9, D7, till AI 

score = 50 

if (score>=70):
    print("A1")
elif
