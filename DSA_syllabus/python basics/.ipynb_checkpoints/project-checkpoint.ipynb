# %% [raw]
# project Description
#
# python basics
# - variable and values
# - data types
# - data structure
# - conditional statement
# - function
# - loops
# - comparism operator
# - boolean operator
# - object and classes

# %% [markdown]
# Variable - They are containers for storing data or values
# any entity or object is a variable
#
# - bucket we store water (bucket is a variable)
# - cup stores water, garri (cup is a variable)
# - shelf stores books, pen and others (shelf is a variabe)
#
# name = "Azeez"
# the name is a variable while Azeez is the value stored in the value
#
# Data types of the values stored in the variable
#
# "Azeez" - any value inside "" '' is called string
#
# age = 34
# 34 any value that is number, the data type is integer
#
# salary = 590.56
#
# 590.56 any value that has decimals, the data type is float
#
# are_you_married = True / False
#
# True or False, any time we see this value, they are called Boolean
#
# status = "accepted" or "rejected"
# "accepted" or "rejected", the value is in a string "" or '' is called String
#
# Boolean values (True or False)
#
# Comparism operator and conditional operators
#
# <,>, =, !=, ==, <=, >=
#
#
# age = 8
#
# age > 40
# False (False is the boolean value)
#
# 'age' == 'Age'
# False (False is the boolean value)
#
# level = 400
#
# level < 100
# False
#
# Logical operator (and, or, not)
# and - means that all conditions must be True to return True
# or - at least one condition should be True to return True else False
# not - the negation (opposite) of the True state of the value
#
#
# Example for and operator
#
# (4 >3) and && (3<1)
# T && F = F
#
# (4==4) and (4<7)
# T and T = T
#
#
# Example for or operator
#
# (3>2) || or (2 ==3)
# T or F = T
#
#
# Example of not T or F
#
# not (3>2)
#
#
# (3>2) = not (T) = F
#
# not (3<1)
#
# (3<1) = not (F) = T
#
# Conditional Statement (if and else, nested if, elif)
#
# Write a conditional Statement that shows the greatest between 2 numbers
#
# number1 = 6
# number2 = 8
#
#
# naming covention
# number 1 (wrong)
# 1 (wrong)
# number-1 (wrong)
#
# number1 (correct)
# number_1 (correct)
#
#
#
# if (number1 >number2):
#     print(number1)
# else:
#     print(number2)
#
# -nested if, or ellif
#
# - data structure with python
# string, list, tuple, set, dictionary
