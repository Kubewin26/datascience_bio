# %%
name = 'Oba is always finishing the lotion'

# %%
name
# Out:
# 'Oba is always finishing the lotion'

# %%
name.find('i')
# Out:
# 4

# %%
q = 'always'
name.find(q)
# Out:
# 7

# %%
name.replace('finishing','using')
# Out:
# 'Oba is always using the lotion'

# %%
name[0:24]
# Out:
# 'Oba is always finishing '

# %%
first_char = name[0:6]

# %%
print('First 5 character : ', first_char)
# Out:
# First 5 character :  Oba is

# %%
last_char = name[-5:]

# %%
print('Last 5 character : ', last_char)
# Out:
# Last 5 character :  otion

# %%
name[0:3]
# Out:
# 'Oba'

# %%
name[::-1]
# Out:
# 'noitol eht gnihsinif syawla si abO'
