# %% [markdown]
# # Deploy a Simple ML Demo with Streamlit
#
# **When:** Week 15 · Session B
# **Goal:** Turn your trained model into a clickable demo for presentations.

# %% [markdown]
# ## Steps
# 1. Train + save a model with `joblib` (see `ML/pipeline/end_to_end_ml_pipeline.ipynb`).
# 2. Create `Deploy/app.py` (template provided in this folder).
# 3. In terminal:
#
# ```bash
# pip install streamlit joblib scikit-learn pandas
# streamlit run Deploy/app.py
# ```
#
# 4. Browser opens → adjust inputs → see prediction.

# %%
# Quick check that streamlit is installed
import importlib.util
print("streamlit installed:", importlib.util.find_spec("streamlit") is not None)
print("joblib installed:", importlib.util.find_spec("joblib") is not None)

# %% [markdown]
# ## Presentation tip
# - 60 seconds: problem
# - 60 seconds: data + cleaning
# - 90 seconds: model + metrics
# - 90 seconds: live Streamlit demo
# - 60 seconds: limitations / next steps
