# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # Groupby
#
# The groupby method allows you to group rows of data together and call aggregate functions

# %%
import pandas as pd
# Create dataframe
data = {'Company':['GOOG','GOOG','MSFT','MSFT','FB','FB'],'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],'Sales':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df.shape
# Out:
# (6, 3)

# %%
df.head(10)
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
df.shape
# Out:
# (6, 3)

# %% [markdown]
# ** Now you can use the .groupby() method to group rows together based on a column name. For instance let's group based on Company. This will create a DataFrameGroupBy object:**

# %%
df.groupby('Company')

# %% [markdown]
# You can save this object as a new variable:

# %%
by_comp = df.groupby("Company")

# %%
by_comp.head()
# Out:
#   Company   Person  Sales
# 0    GOOG      Sam    200
# 1    GOOG  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %% [markdown]
# And then call aggregate methods off the object:

# %%
by_comp.sum()
# Out:
#              Person  Sales
# Company
# FB        CarlSarah    593
# GOOG     SamCharlie    320
# MSFT     AmyVanessa    464

# %%
by_comp.sum()
# Out:
#              Person  Sales
# Company
# FB        CarlSarah    593
# GOOG     SamCharlie    320
# MSFT     AmyVanessa    464

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOG     Charlie    120
# MSFT         Amy    124

# %%
by_comp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOG         Sam    200
# MSFT     Vanessa    340

# %%
by_comp.count()
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOG          2      2
# MSFT          2      2

# %%
by_comp.describe() #stastistical analsysis
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOG      2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
by_comp.describe().transpose()['MSFT']
# Out:
# Sales  count      2.000000
#        mean     232.000000
#        std      152.735065
#        min      124.000000
#        25%      178.000000
#        50%      232.000000
#        75%      286.000000
#        max      340.000000
# Name: MSFT, dtype: float64

# %%
by_comp.describe().transpose()['FB']
# Out:
# Sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# Name: FB, dtype: float64

# %%
df['profit'] = [100,200,300,400,500,600]

# %%
df.head(7)
# Out:
#   Company   Person  Sales  profit
# 0    GOOG      Sam    200     100
# 1    GOOG  Charlie    120     200
# 2    MSFT      Amy    340     300
# 3    MSFT  Vanessa    124     400
# 4      FB     Carl    243     500
# 5      FB    Sarah    350     600

# %%
new =df.groupby('Company').sum()

# %%
new
# Out:
#              Person  Sales  profit
# Company
# FB        CarlSarah    593    1100
# GOOG     SamCharlie    320     300
# MSFT     AmyVanessa    464     700

# %%
df.shape
# Out:
# (6, 4)

# %%
#class work 
#create a new column named supervisor, assign values, them split 
#add the new column to the data data frame
#groupby and perfom some aggregrate function 

df['supervisor'] = 'ola femi ope korede funmilayo seyi'.split()

# %%
df.head()
# Out:
#   Company   Person  Sales supervisor
# 0    GOOG      Sam    200        ola
# 1    GOOG  Charlie    120       femi
# 2    MSFT      Amy    340        ope
# 3    MSFT  Vanessa    124     korede
# 4      FB     Carl    243  funmilayo

# %%
new =df.groupby('Company').sum()

# %%
new
# Out:
#              Person  Sales     supervisor
# Company
# FB        CarlSarah    593  funmilayoseyi
# GOOG     SamCharlie    320        olafemi
# MSFT     AmyVanessa    464      opekorede

# %% [markdown]
# # Great Job!
