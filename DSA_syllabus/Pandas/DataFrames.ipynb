# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # DataFrames
#
# DataFrames are the workhorse of pandas and are directly inspired by the R programming language. We can think of a DataFrame as a bunch of Series objects put together to share the same index. Let's use pandas to explore this topic!

# %%
import pandas as pd
import numpy as np

# %%
from numpy.random import randn
np.random.seed(101) #seed allows us to retain the random generated

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data = pd.DataFrame(randn(5,4),index=['A', 'B', 'C', 'D', 'E'],columns='W X Y Z'.split())
#5rows, 4 columns

# %%
data
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
data.head() #top 5 records (rows and columns)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
data.head(7)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
data.head(10) #show the top 10 records
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
data.tail(10) #bottom last 5records
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
data.shape #shape shows the number of rows and columns 5 rows, 4 columns
# Out:
# (5, 4)

# %% [markdown]
# ## Selection and Indexing
#
# Let's learn the various methods to grab data from a DataFrame

# %%
data['Y']
# Out:
# A    0.907969
# B   -0.848077
# C    0.528813
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %%
# Pass a list of column names
data[['W','Z', 'X']]
# Out:
#           W         Z         X
# A  2.706850  0.503826  0.628133
# B  0.651118  0.605965 -0.319318
# C -2.018168 -0.589001  0.740122
# D  0.188695  0.955057 -0.758872
# E  0.190794  0.683509  1.978757

# %%
# SQL Syntax (NOT RECOMMENDED!)
data['W']
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %% [markdown]
# DataFrame Columns are just Series

# %%
type(data['W'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# **Creating a new column:**

# %%
data['Sum of WY'] = data['W'] + data['Y']
data['Sum of XZ'] = data['X'] + data['Z']



#data['age'] = 2025 - data['dob']
#create a column called Age, a column called year
#data['age'] = 2025 - data['year']

# %%
data.head()
# Out:
#           W         X         Y         Z  Sum of WY  Sum of XZ
# A  2.706850  0.628133  0.907969  0.503826   3.614819   1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959   0.286647
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355   0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542   0.196184
# E  0.190794  1.978757  2.605967  0.683509   2.796762   2.662266

# %%
data
# Out:
#           W         X         Y         Z  Sum of WY  Sum of XZ
# A  2.706850  0.628133  0.907969  0.503826   3.614819   1.131958
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959   0.286647
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355   0.151122
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542   0.196184
# E  0.190794  1.978757  2.605967  0.683509   2.796762   2.662266

# %%
data.drop('Sum of XZ',axis=1, inplace=True) #axis =1 means in a column, axis=0 means in a row, inplace = True (drop permanently)

# %%
data.head()
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %% [markdown]
# ** Removing Columns**

# %%
data.drop(['Sum of WY', 'X'],axis=1)
# Out:
#           W         Y         Z
# A  2.706850  0.907969  0.503826
# B  0.651118 -0.848077  0.605965
# C -2.018168  0.528813 -0.589001
# D  0.188695 -0.933237  0.955057
# E  0.190794  2.605967  0.683509

# %%
# Not inplace unless specified!
data
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %% [markdown]
# ** Selecting Rows**

# %%
data.loc['A'] #access the row
# Out:
# W            2.706850
# X            0.628133
# Y            0.907969
# Z            0.503826
# Sum of WY    3.614819
# Name: A, dtype: float64

# %%
data['X'] #acces the column
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64

# %%
data.loc['E']
# Out:
# W            0.190794
# X            1.978757
# Y            2.605967
# Z            0.683509
# Sum of WY    2.796762
# Name: E, dtype: float64

# %% [markdown]
# Or select based off of position instead of label

# %%
data.head()
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data.iloc[2] #index
# Out:
# W           -2.018168
# X            0.740122
# Y            0.528813
# Z           -0.589001
# Sum of WY   -1.489355
# Name: C, dtype: float64

# %% [markdown]
# ** Selecting subset of rows and columns **

# %%
data
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data.loc['B','Y']
# Out:
# -0.8480769834036315

# %%
data.loc[['A','B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# ### Conditional Selection
#
# An important feature of pandas is conditional selection using bracket notation, very similar to numpy:

# %%
data
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data[data<0]
# Out:
#           W        X         Y         Z  Sum of WY
# A       NaN      NaN -0.376519       NaN        NaN
# B       NaN      NaN -0.031160       NaN        NaN
# C -1.005187 -0.74179       NaN -0.732845  -0.818062
# D -1.382920      NaN       NaN -2.141212  -0.421462
# E       NaN      NaN -1.046780       NaN  -0.054206

# %%
data[data>0]
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118       NaN       NaN  0.605965        NaN
# C       NaN  0.740122  0.528813       NaN        NaN
# D  0.188695       NaN       NaN  0.955057        NaN
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data[data['W']<0]
# Out:
#           W         X         Y         Z  Sum of WY
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355

# %%
data[data['W']>0]['W']
# Out:
# A    2.706850
# B    0.651118
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
data[data>0][['Y','X']]
# Out:
#           Y         X
# A  0.907969  0.628133
# B       NaN       NaN
# C  0.528813  0.740122
# D       NaN       NaN
# E  2.605967  1.978757

# %% [markdown]
# For two conditions you can use | and & with parenthesis:

# %%
data[(data>0) & (data['Y'] > 1)]
# Out:
#     W   X   Y   Z  Sum of WY
# A NaN NaN NaN NaN        NaN
# B NaN NaN NaN NaN        NaN
# C NaN NaN NaN NaN        NaN
# D NaN NaN NaN NaN        NaN
# E NaN NaN NaN NaN        NaN

# %% [markdown]
# ## More Index Details
#
# Let's discuss some more features of indexing, including resetting the index or setting it something else. We'll also talk about index hierarchy!

# %%
data
# Out:
#           W         X         Y         Z  Sum of WY
# A  2.706850  0.628133  0.907969  0.503826   3.614819
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
# Reset to default 0,1...n index
data.reset_index(inplace=True)  #reset the value or the index to default

# %%
data
# Out:
#   index         W         X         Y         Z  Sum of WY
# 0     A  2.706850  0.628133  0.907969  0.503826   3.614819
# 1     B  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# 2     C -2.018168  0.740122  0.528813 -0.589001  -1.489355
# 3     D  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# 4     E  0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data.drop('index', axis=1, inplace=True)

# %%
df.drop(['level_0','index'], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['W', 'X', 'Y', 'Z', 'Sum of WY'], dtype='object')

# %%
newind = 'CA NY WY OR CO'.split()

#newind = ['s', 'd']

# %%
data['States'] = newind

# %%
data['states'] = 'CA NY WY OR CO'.split()

# %%
data
# Out:
#           W         X         Y         Z  Sum of WY States
# A  2.706850  0.628133  0.907969  0.503826   3.614819     CA
# B  0.651118 -0.319318 -0.848077  0.605965  -0.196959     NY
# C -2.018168  0.740122  0.528813 -0.589001  -1.489355     WY
# D  0.188695 -0.758872 -0.933237  0.955057  -0.744542     OR
# E  0.190794  1.978757  2.605967  0.683509   2.796762     CO

# %%
data.set_index('States', inplace=True)

# %%
data.columns
# Out:
# Index(['W', 'X', 'Y', 'Z', 'Sum of WY'], dtype='object')

# %%
data
# Out:
#                W         X         Y         Z  Sum of WY
# States
# CA      2.706850  0.628133  0.907969  0.503826   3.614819
# NY      0.651118 -0.319318 -0.848077  0.605965  -0.196959
# WY     -2.018168  0.740122  0.528813 -0.589001  -1.489355
# OR      0.188695 -0.758872 -0.933237  0.955057  -0.744542
# CO      0.190794  1.978757  2.605967  0.683509   2.796762

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5 entries, CA to CO
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   W          5 non-null      float64
#  1   X          5 non-null      float64
#  2   Y          5 non-null      float64
#  3   Z          5 non-null      float64
#  4   Sum of WY  5 non-null      float64
# dtypes: float64(5)
# memory usage: 240.0+ bytes

# %%
data.shape
# Out:
# (5, 5)

# %%
data.isnull().sum()
# Out:
# W            0
# X            0
# Y            0
# Z            0
# Sum of WY    0
# dtype: int64

# %%
data.isnull().sum() #to check if there are missing data 

data['W']
# Out:
# A    0.302665
# B   -0.134841
# C    0.807706
# D   -0.497104
# E   -0.116773
# Name: W, dtype: float64

# %%
data
# Out:
#                W         X         Y         Z  Sum of WY
# States
# CA      2.706850  0.628133  0.907969  0.503826   3.614819
# NY      0.651118 -0.319318 -0.848077  0.605965  -0.196959
# WY     -2.018168  0.740122  0.528813 -0.589001  -1.489355
# OR      0.188695 -0.758872 -0.933237  0.955057  -0.744542
# CO      0.190794  1.978757  2.605967  0.683509   2.796762

# %%
df.set_index('States',inplace=True)

# %%
data.reset_index(inplace = True)

# %%
data
# Out:
#   States         W         X         Y         Z  Sum of WY
# 0     CA  2.706850  0.628133  0.907969  0.503826   3.614819
# 1     NY  0.651118 -0.319318 -0.848077  0.605965  -0.196959
# 2     WY -2.018168  0.740122  0.528813 -0.589001  -1.489355
# 3     OR  0.188695 -0.758872 -0.933237  0.955057  -0.744542
# 4     CO  0.190794  1.978757  2.605967  0.683509   2.796762

# %% [markdown]
# ## Multi-Index and Index Hierarchy
#
# Let us go over how to work with Multi-Index, first we'll create a quick example of what a Multi-Indexed DataFrame would look like:

# %%
# Index Levels
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex([('G1', 1),
#             ('G1', 2),
#             ('G1', 3),
#             ('G2', 1),
#             ('G2', 2),
#             ('G2', 3)],
#            )

# %%
df = pd.DataFrame(np.random.randn(6,2),index=hier_index,columns=['A','B'])
df
# Out:
#              A         B
# G1 1  0.302665  1.693723
#    2 -1.706086 -1.159119
#    3 -0.134841  0.390528
# G2 1  0.166905  0.184502
#    2  0.807706  0.072960
#    3  0.638787  0.329646

# %% [markdown]
# Now let's show how to index this! For index hierarchy we use df.loc[], if this was on the columns axis, you would just use normal bracket notation df[]. Calling one level of the index returns the sub-dataframe:

# %%
df.loc['G1']
# Out:
#           A         B
# 1  0.302665  1.693723
# 2 -1.706086 -1.159119
# 3 -0.134841  0.390528

# %%
df.loc['G1'].loc[1]
# Out:
# A    0.302665
# B    1.693723
# Name: 1, dtype: float64

# %%
df.index.names
# Out:
# FrozenList([None, None])

# %%
df.index.names = ['Group','Num']

# %%
df
# Out:
#                   A         B
# Group Num
# G1    1    0.147027 -0.479448
#       2    0.558769  1.024810
#       3   -0.925874  1.862864
# G2    1   -1.133817  0.610478
#       2    0.386030  2.084019
#       3   -0.376519  0.230336

# %%
df.xs('G1')
# Out:
#             A         B
# Num
# 1    0.147027 -0.479448
# 2    0.558769  1.024810
# 3   -0.925874  1.862864

# %%
df.xs(['G1',1])
# Out:
# A    0.147027
# B   -0.479448
# Name: (G1, 1), dtype: float64

# %%
df.xs(1,level='Num')
# Out:
#               A         B
# Group
# G1     0.147027 -0.479448
# G2    -1.133817  0.610478

# %% [markdown]
# # Great Job!
